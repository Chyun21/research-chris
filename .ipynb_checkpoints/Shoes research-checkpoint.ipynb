# %%
# Run this cell to set up the notebook, but please don't change it.
import numpy as np
import math
from datascience import *
import matplotlib as plot
# These lines set up the plotting functionality and formatting.
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
shoes = Table().read_table('Shoe Sales.csv')

# %%
shoes
# Out:
# Order Date | Brand  | Sneaker Name                                  | Sale Price | Retail Price | Release Date | Shoe Size | Buyer Region
# 9/1/17     |  Yeezy | Adidas-Yeezy-Boost-350-Low-V2-Beluga          | $1,097     | $220         | 9/24/16      | 11        | California
# 9/1/17     |  Yeezy | Adidas-Yeezy-Boost-350-V2-Core-Black-Copper   | $685       | $220         | 11/23/16     | 11        | California
# 9/1/17     |  Yeezy | Adidas-Yeezy-Boost-350-V2-Core-Black-Green    | $690       | $220         | 11/23/16     | 11        | California
# 9/1/17     |  Yeezy | Adidas-Yeezy-Boost-350-V2-Core-Black-Red      | $1,075     | $220         | 11/23/16     | 11.5      | Kentucky
# 9/1/17     |  Yeezy | Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017 | $828       | $220         | 2/11/17      | 11        | Rhode Island
# 9/1/17     |  Yeezy | Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017 | $798       | $220         | 2/11/17      | 8.5       | Michigan
# 9/1/17     |  Yeezy | Adidas-Yeezy-Boost-350-V2-Core-Black-White    | $784       | $220         | 12/17/16     | 11        | California
# 9/1/17     |  Yeezy | Adidas-Yeezy-Boost-350-V2-Cream-White         | $460       | $220         | 4/29/17      | 10        | New York
# 9/1/17     |  Yeezy | Adidas-Yeezy-Boost-350-V2-Cream-White         | $465       | $220         | 4/29/17      | 11        | Kansas
# 9/1/17     |  Yeezy | Adidas-Yeezy-Boost-350-V2-Cream-White         | $465       | $220         | 4/29/17      | 11        | Florida
# ... (99946 rows omitted)

# %%
sneakernames = shoes.group('Sneaker Name')

# %%
sneakernames.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Sneaker Name</th> <th>count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-Low-Moonrock              </td> <td>100  </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-Low-Oxford-Tan            </td> <td>70   </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015     </td> <td>95   </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016     </td> <td>122  </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-Low-Turtledove            </td> <td>68   </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-Low-V2-Beluga             </td> <td>498  </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Beluga-2pt0            </td> <td>10395</td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Blue-Tint              </td> <td>9297 </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Copper      </td> <td>225  </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Green       </td> <td>196  </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red         </td> <td>302  </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017    </td> <td>969  </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Core-Black-White       </td> <td>621  </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Cream-White            </td> <td>9097 </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow     </td> <td>4854 </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Sesame                 </td> <td>5553 </td>
#         </tr>
#         <tr>
#             <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>10110</td>
#         </tr>
#         <tr>
#             <td>Air-Jordan-1-Retro-High-Off-White-Chicago        </td> <td>755  </td>
#         </tr>
#         <tr>
#             <td>Air-Jordan-1-Retro-High-Off-White-University-Blue</td> <td>4635 </td>
#         </tr>
#         <tr>
#             <td>Air-Jordan-1-Retro-High-Off-White-White          </td> <td>313  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Force-1-Low-Off-White                   </td> <td>476  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Force-1-Low-Off-White-Black-White       </td> <td>960  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Force-1-Low-Off-White-Volt              </td> <td>1019 </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Force-1-Low-Virgil-Abloh-Off-White-AF100</td> <td>31   </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Max-90-Off-White                        </td> <td>627  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Max-90-Off-White-Black                  </td> <td>722  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Max-90-Off-White-Desert-Ore             </td> <td>649  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Max-97-Off-White                        </td> <td>544  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Max-97-Off-White-Black                  </td> <td>289  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Max-97-Off-White-Elemental-Rose-Queen   </td> <td>216  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Max-97-Off-White-Menta                  </td> <td>343  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Presto-Off-White                        </td> <td>596  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Presto-Off-White-Black-2018             </td> <td>1884 </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-Presto-Off-White-White-2018             </td> <td>1883 </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-VaporMax-Off-White                      </td> <td>525  </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-VaporMax-Off-White-2018                 </td> <td>1591 </td>
#         </tr>
#         <tr>
#             <td>Nike-Air-VaporMax-Off-White-Black                </td> <td>1313 </td>
#         </tr>
#         <tr>
#             <td>Nike-Blazer-Mid-Off-White                        </td> <td>501  </td>
#         </tr>
#         <tr>
#             <td>Nike-Blazer-Mid-Off-White-All-Hallows-Eve        </td> <td>1435 </td>
#         </tr>
#         <tr>
#             <td>Nike-Blazer-Mid-Off-White-Grim-Reaper            </td> <td>1398 </td>
#         </tr>
#         <tr>
#             <td>Nike-Blazer-Mid-Off-White-Wolf-Grey              </td> <td>288  </td>
#         </tr>
#         <tr>
#             <td>Nike-React-Hyperdunk-2017-Flyknit-Off-White      </td> <td>484  </td>
#         </tr>
#         <tr>
#             <td>Nike-Zoom-Fly-Mercurial-Off-White-Black          </td> <td>645  </td>
#         </tr>
#         <tr>
#             <td>Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange   </td> <td>656  </td>
#         </tr>
#         <tr>
#             <td>Nike-Zoom-Fly-Off-White                          </td> <td>435  </td>
#         </tr>
#         <tr>
#             <td>Nike-Zoom-Fly-Off-White-Black-Silver             </td> <td>1222 </td>
#         </tr>
#         <tr>
#             <td>Nike-Zoom-Fly-Off-White-Pink                     </td> <td>1359 </td>
#         </tr>
#         <tr>
#             <td>adidas-Yeezy-Boost-350-V2-Butter                 </td> <td>11423</td>
#         </tr>
#         <tr>
#             <td>adidas-Yeezy-Boost-350-V2-Static                 </td> <td>4983 </td>
#         </tr>
#         <tr>
#             <td>adidas-Yeezy-Boost-350-V2-Static-Reflective      </td> <td>3184 </td>
#         </tr>
#     </tbody>
# </table>

# %%
def get_row(sneaker):
    return shoes.where('Sneaker Name', are.containing(sneaker))

def plotit(sneaker):
    row = shoes.where('Sneaker Name', are.containing('adidas')).where('Shoe Size', are.below(7))
    x = row.column('Order Date')
    y = row.column('Sale Price')
    plots.title('Adidas Sales Price')
    plots.xlabel('Order Date')
    plots.ylabel('Sale Price')
    plots.tick_params(axis='x', colors='#f0f0f0')
    
    plots.tick_params(axis='y', colors='#f0f0f0')
    plots.plot(x, y)

for name in sneakernames.column(0)[0:20]:
    plotit(name)

# %%
def get_row(sneaker):
    return shoes.where('Sneaker Name', are.containing(sneaker))

def plotit(sneaker):
    row = shoes.where('Sneaker Name', are.containing('Nike')).where('Shoe Size', are.below(7))
    x = row.column('Order Date')
    y = row.column('Sale Price')
    plots.title('Nike Sales Price')
    plots.xlabel('Order Date')
    plots.ylabel('Sale Price')
    plots.tick_params(axis='x', colors='#f0f0f0')
    
    plots.tick_params(axis='y', colors='#f0f0f0')

    
    

    plots.plot(x, y)
    
for name in sneakernames.column(0)[0:20]:
    plotit(name)

# %%
shoes.column(2)
# Out:
# array(['Adidas-Yeezy-Boost-350-Low-V2-Beluga',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-Copper',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-Green', ...,
#        'adidas-Yeezy-Boost-350-V2-Static-Reflective',
#        'adidas-Yeezy-Boost-350-V2-Static-Reflective',
#        'adidas-Yeezy-Boost-350-V2-Static-Reflective'], dtype='<U49')

# %%
colors = ['Beluga','Cream', 'White','Copper','Green','Red','Zebra','Black','Moonrock','Chicago','Tan','Turtledove','Blue','Yellow','Butter','Sesame','Static','Reflective','Desert','University','Volt','Pink','Silver','Eve','Rose','Menta','Reaper','Orange']

# %%
shoedict = {}
counter = 0
for shoe in shoes.column(2):
    colors_list = []
    shoe_list = shoe.split("-")
    for char in shoe_list:
        if char in colors and 'Off' not in colors:
            colors_list.append(char)
    shoedict[counter] = colors_list
    counter += 1

# %%
shoedict
# Out:
# {0: ['Beluga'],
#  1: ['Black', 'Copper'],
#  2: ['Black', 'Green'],
#  3: ['Black', 'Red'],
#  4: ['Black', 'Red'],
#  5: ['Black', 'Red'],
#  6: ['Black', 'White'],
#  7: ['Cream', 'White'],
#  8: ['Cream', 'White'],
#  9: ['Cream', 'White'],
#  10: ['Cream', 'White'],
#  11: ['Cream', 'White'],
#  12: ['Cream', 'White'],
#  13: ['Zebra'],
#  14: ['Zebra'],
#  15: ['Zebra'],
#  16: ['Zebra'],
#  17: ['Zebra'],
#  18: ['Zebra'],
#  19: ['Zebra'],
#  20: ['Zebra'],
#  21: ['Zebra'],
#  22: ['Zebra'],
#  23: ['Beluga'],
#  24: ['Black', 'Red'],
#  25: ['Black', 'Red'],
#  26: ['Black', 'Red'],
#  27: ['Black', 'White'],
#  28: ['Cream', 'White'],
#  29: ['Cream', 'White'],
#  30: ['Cream', 'White'],
#  31: ['Zebra'],
#  32: ['Zebra'],
#  33: ['Zebra'],
#  34: ['Zebra'],
#  35: ['Zebra'],
#  36: ['Zebra'],
#  37: ['Zebra'],
#  38: ['Beluga'],
#  39: ['Black', 'Red'],
#  40: ['Black', 'Red'],
#  41: ['Black', 'Red'],
#  42: ['Black', 'White'],
#  43: ['Black', 'White'],
#  44: ['Cream', 'White'],
#  45: ['Cream', 'White'],
#  46: ['Cream', 'White'],
#  47: ['Cream', 'White'],
#  48: ['Cream', 'White'],
#  49: ['Zebra'],
#  50: ['Zebra'],
#  51: ['Zebra'],
#  52: ['Zebra'],
#  53: ['Zebra'],
#  54: ['Beluga'],
#  55: ['Black', 'Red'],
#  56: ['Black', 'White'],
#  57: ['Black', 'White'],
#  58: ['Cream', 'White'],
#  59: ['Cream', 'White'],
#  60: ['Cream', 'White'],
#  61: ['Cream', 'White'],
#  62: ['Cream', 'White'],
#  63: ['Zebra'],
#  64: ['Zebra'],
#  65: ['Zebra'],
#  66: ['Zebra'],
#  67: ['Zebra'],
#  68: ['Zebra'],
#  69: ['Zebra'],
#  70: ['Zebra'],
#  71: ['Beluga'],
#  72: ['Black', 'Copper'],
#  73: ['Black', 'Red'],
#  74: ['Black', 'Red'],
#  75: ['Black', 'Red'],
#  76: ['Black', 'White'],
#  77: ['Black', 'White'],
#  78: ['Cream', 'White'],
#  79: ['Cream', 'White'],
#  80: ['Cream', 'White'],
#  81: ['Cream', 'White'],
#  82: ['Cream', 'White'],
#  83: ['Cream', 'White'],
#  84: ['Cream', 'White'],
#  85: ['Zebra'],
#  86: ['Zebra'],
#  87: ['Zebra'],
#  88: ['Zebra'],
#  89: ['Zebra'],
#  90: ['Zebra'],
#  91: ['Zebra'],
#  92: ['Zebra'],
#  93: ['Beluga'],
#  94: ['Black', 'Copper'],
#  95: ['Black', 'Green'],
#  96: ['Black', 'Red'],
#  97: ['Black', 'Red'],
#  98: ['Black', 'White'],
#  99: ['Black', 'White'],
#  100: ['Cream', 'White'],
#  101: ['Cream', 'White'],
#  102: ['Cream', 'White'],
#  103: ['Cream', 'White'],
#  104: ['Cream', 'White'],
#  105: ['Zebra'],
#  106: ['Zebra'],
#  107: ['Zebra'],
#  108: ['Zebra'],
#  109: ['Zebra'],
#  110: ['Zebra'],
#  111: ['Zebra'],
#  112: ['Moonrock'],
#  113: ['Beluga'],
#  114: ['Black', 'Copper'],
#  115: ['Black', 'Red'],
#  116: ['Black', 'Red'],
#  117: ['Black', 'Red'],
#  118: ['Black', 'Red'],
#  119: ['Black', 'White'],
#  120: ['Cream', 'White'],
#  121: ['Cream', 'White'],
#  122: ['Cream', 'White'],
#  123: ['Cream', 'White'],
#  124: ['Zebra'],
#  125: ['Zebra'],
#  126: ['Zebra'],
#  127: ['Zebra'],
#  128: ['White'],
#  129: ['White'],
#  130: ['White'],
#  131: ['White'],
#  132: ['White'],
#  133: ['Beluga'],
#  134: ['Black', 'Red'],
#  135: ['Black', 'Red'],
#  136: ['Black', 'White'],
#  137: ['Black', 'White'],
#  138: ['Cream', 'White'],
#  139: ['Cream', 'White'],
#  140: ['Cream', 'White'],
#  141: ['Cream', 'White'],
#  142: ['Zebra'],
#  143: ['Zebra'],
#  144: ['Zebra'],
#  145: ['Zebra'],
#  146: ['Zebra'],
#  147: ['Zebra'],
#  148: ['Zebra'],
#  149: ['White', 'Chicago'],
#  150: ['White', 'Chicago'],
#  151: ['White'],
#  152: ['White'],
#  153: ['White'],
#  154: ['White'],
#  155: ['White'],
#  156: ['Black'],
#  157: ['Black', 'Green'],
#  158: ['Black', 'Red'],
#  159: ['Black', 'Red'],
#  160: ['Black', 'Red'],
#  161: ['Black', 'White'],
#  162: ['Cream', 'White'],
#  163: ['Cream', 'White'],
#  164: ['Cream', 'White'],
#  165: ['Cream', 'White'],
#  166: ['Cream', 'White'],
#  167: ['Zebra'],
#  168: ['Zebra'],
#  169: ['Zebra'],
#  170: ['Zebra'],
#  171: ['Zebra'],
#  172: ['White', 'Chicago'],
#  173: ['White', 'Chicago'],
#  174: ['White'],
#  175: ['White'],
#  176: ['White'],
#  177: ['White'],
#  178: ['White'],
#  179: ['Black'],
#  180: ['Beluga'],
#  181: ['Black', 'Green'],
#  182: ['Black', 'Green'],
#  183: ['Black', 'Red'],
#  184: ['Black', 'Red'],
#  185: ['Black', 'White'],
#  186: ['Cream', 'White'],
#  187: ['Cream', 'White'],
#  188: ['Cream', 'White'],
#  189: ['Zebra'],
#  190: ['Zebra'],
#  191: ['Zebra'],
#  192: ['Zebra'],
#  193: ['Zebra'],
#  194: ['White', 'Chicago'],
#  195: ['White'],
#  196: ['White'],
#  197: ['White'],
#  198: ['White'],
#  199: ['White'],
#  200: ['White'],
#  201: ['White'],
#  202: ['White'],
#  203: ['White'],
#  204: ['Tan'],
#  205: ['Beluga'],
#  206: ['Beluga'],
#  207: ['Black', 'Green'],
#  208: ['Black', 'Red'],
#  209: ['Black', 'Red'],
#  210: ['Black', 'Red'],
#  211: ['Black', 'White'],
#  212: ['Cream', 'White'],
#  213: ['Cream', 'White'],
#  214: ['Cream', 'White'],
#  215: ['Cream', 'White'],
#  216: ['Zebra'],
#  217: ['Zebra'],
#  218: ['Zebra'],
#  219: ['Zebra'],
#  220: ['Zebra'],
#  221: ['Zebra'],
#  222: ['White', 'Chicago'],
#  223: ['White'],
#  224: ['White'],
#  225: ['White'],
#  226: ['White'],
#  227: ['White'],
#  228: ['White'],
#  229: ['White'],
#  230: ['White'],
#  231: ['White'],
#  232: ['White'],
#  233: ['White'],
#  234: ['White'],
#  235: ['Black'],
#  236: ['Beluga'],
#  237: ['Beluga'],
#  238: ['Black', 'Green'],
#  239: ['Black', 'Green'],
#  240: ['Black', 'Red'],
#  241: ['Black', 'Red'],
#  242: ['Black', 'Red'],
#  243: ['Cream', 'White'],
#  244: ['Cream', 'White'],
#  245: ['Cream', 'White'],
#  246: ['Cream', 'White'],
#  247: ['Cream', 'White'],
#  248: ['Cream', 'White'],
#  249: ['Cream', 'White'],
#  250: ['Zebra'],
#  251: ['Zebra'],
#  252: ['Zebra'],
#  253: ['Zebra'],
#  254: ['Zebra'],
#  255: ['Zebra'],
#  256: ['Zebra'],
#  257: ['Zebra'],
#  258: ['Zebra'],
#  259: ['White', 'Chicago'],
#  260: ['White'],
#  261: ['White'],
#  262: ['White'],
#  263: ['White'],
#  264: ['White'],
#  265: ['White'],
#  266: ['White'],
#  267: ['White'],
#  268: ['Beluga'],
#  269: ['Black', 'Copper'],
#  270: ['Black', 'Green'],
#  271: ['Black', 'Red'],
#  272: ['Black', 'White'],
#  273: ['Black', 'White'],
#  274: ['Cream', 'White'],
#  275: ['Cream', 'White'],
#  276: ['Cream', 'White'],
#  277: ['Cream', 'White'],
#  278: ['Cream', 'White'],
#  279: ['Zebra'],
#  280: ['Zebra'],
#  281: ['Zebra'],
#  282: ['Zebra'],
#  283: ['Zebra'],
#  284: ['Zebra'],
#  285: ['Zebra'],
#  286: ['Zebra'],
#  287: ['White', 'Chicago'],
#  288: ['White', 'Chicago'],
#  289: ['White', 'Chicago'],
#  290: ['White'],
#  291: ['White'],
#  292: ['White'],
#  293: ['White'],
#  294: ['White'],
#  295: ['White'],
#  296: ['White'],
#  297: ['Black'],
#  298: ['Turtledove'],
#  299: ['Beluga'],
#  300: ['Black', 'Green'],
#  301: ['Black', 'Red'],
#  302: ['Black', 'Red'],
#  303: ['Black', 'Red'],
#  304: ['Black', 'White'],
#  305: ['Black', 'White'],
#  306: ['Cream', 'White'],
#  307: ['Cream', 'White'],
#  308: ['Cream', 'White'],
#  309: ['Zebra'],
#  310: ['Zebra'],
#  311: ['Zebra'],
#  312: ['Zebra'],
#  313: ['Zebra'],
#  314: ['Zebra'],
#  315: ['Zebra'],
#  316: ['Zebra'],
#  317: ['White', 'Chicago'],
#  318: ['White', 'Chicago'],
#  319: ['White', 'Chicago'],
#  320: ['White'],
#  321: ['White'],
#  322: ['White'],
#  323: ['White'],
#  324: ['White'],
#  325: ['White'],
#  326: ['Turtledove'],
#  327: ['Beluga'],
#  328: ['Beluga'],
#  329: ['Black', 'Red'],
#  330: ['Black', 'Red'],
#  331: ['Black', 'White'],
#  332: ['Cream', 'White'],
#  333: ['Cream', 'White'],
#  334: ['Cream', 'White'],
#  335: ['Zebra'],
#  336: ['Zebra'],
#  337: ['Zebra'],
#  338: ['Zebra'],
#  339: ['Zebra'],
#  340: ['Zebra'],
#  341: ['Zebra'],
#  342: ['Zebra'],
#  343: ['White', 'Chicago'],
#  344: ['White', 'Chicago'],
#  345: ['White', 'Chicago'],
#  346: ['White', 'Chicago'],
#  347: ['White'],
#  348: ['White'],
#  349: ['White'],
#  350: ['White'],
#  351: ['White'],
#  352: ['Beluga'],
#  353: ['Black', 'Red'],
#  354: ['Black', 'Red'],
#  355: ['Cream', 'White'],
#  356: ['Cream', 'White'],
#  357: ['Cream', 'White'],
#  358: ['Cream', 'White'],
#  359: ['Cream', 'White'],
#  360: ['Cream', 'White'],
#  361: ['Cream', 'White'],
#  362: ['Zebra'],
#  363: ['Zebra'],
#  364: ['Zebra'],
#  365: ['Zebra'],
#  366: ['White', 'Chicago'],
#  367: ['White', 'Chicago'],
#  368: ['White'],
#  369: ['White'],
#  370: ['White'],
#  371: ['White'],
#  372: ['White'],
#  373: ['Beluga'],
#  374: ['Beluga'],
#  375: ['Black', 'Green'],
#  376: ['Black', 'Red'],
#  377: ['Black', 'Red'],
#  378: ['Black', 'Red'],
#  379: ['Cream', 'White'],
#  380: ['Cream', 'White'],
#  381: ['Cream', 'White'],
#  382: ['Cream', 'White'],
#  383: ['Zebra'],
#  384: ['Zebra'],
#  385: ['Zebra'],
#  386: ['Zebra'],
#  387: ['White', 'Chicago'],
#  388: ['White'],
#  389: ['White'],
#  390: ['White'],
#  391: ['White'],
#  392: ['White'],
#  393: ['White'],
#  394: ['Beluga'],
#  395: ['Black', 'Green'],
#  396: ['Black', 'Red'],
#  397: ['Black', 'Red'],
#  398: ['Black', 'White'],
#  399: ['Cream', 'White'],
#  400: ['Cream', 'White'],
#  401: ['Cream', 'White'],
#  402: ['Cream', 'White'],
#  403: ['Cream', 'White'],
#  404: ['Cream', 'White'],
#  405: ['Zebra'],
#  406: ['Zebra'],
#  407: ['Zebra'],
#  408: ['Zebra'],
#  409: ['Zebra'],
#  410: ['Zebra'],
#  411: ['Zebra'],
#  412: ['Zebra'],
#  413: ['White', 'Chicago'],
#  414: ['White', 'Chicago'],
#  415: ['White'],
#  416: ['White'],
#  417: ['White'],
#  418: ['White'],
#  419: ['White'],
#  420: ['White'],
#  421: ['Beluga'],
#  422: ['Black', 'Red'],
#  423: ['Black', 'Red'],
#  424: ['Black', 'White'],
#  425: ['Cream', 'White'],
#  426: ['Cream', 'White'],
#  427: ['Cream', 'White'],
#  428: ['Cream', 'White'],
#  429: ['Cream', 'White'],
#  430: ['Cream', 'White'],
#  431: ['Zebra'],
#  432: ['Zebra'],
#  433: ['Zebra'],
#  434: ['Zebra'],
#  435: ['Zebra'],
#  436: ['White', 'Chicago'],
#  437: ['White', 'Chicago'],
#  438: ['White'],
#  439: ['White'],
#  440: ['White'],
#  441: ['White'],
#  442: ['White'],
#  443: ['White'],
#  444: ['White'],
#  445: ['Black'],
#  446: ['Beluga'],
#  447: ['Black', 'Green'],
#  448: ['Black', 'Red'],
#  449: ['Black', 'White'],
#  450: ['Cream', 'White'],
#  451: ['Cream', 'White'],
#  452: ['Cream', 'White'],
#  453: ['Cream', 'White'],
#  454: ['Cream', 'White'],
#  455: ['Zebra'],
#  456: ['Zebra'],
#  457: ['Zebra'],
#  458: ['Zebra'],
#  459: ['Zebra'],
#  460: ['Zebra'],
#  461: ['Zebra'],
#  462: ['Zebra'],
#  463: ['Zebra'],
#  464: ['Zebra'],
#  465: ['White', 'Chicago'],
#  466: ['White', 'Chicago'],
#  467: ['White'],
#  468: ['White'],
#  469: ['White'],
#  470: ['White'],
#  471: ['White'],
#  472: ['White'],
#  473: ['White'],
#  474: ['White'],
#  475: ['White'],
#  476: ['Turtledove'],
#  477: ['Beluga'],
#  478: ['Black', 'Copper'],
#  479: ['Black', 'Green'],
#  480: ['Black', 'Red'],
#  481: ['Black', 'Red'],
#  482: ['Black', 'Red'],
#  483: ['Black', 'White'],
#  484: ['Cream', 'White'],
#  485: ['Cream', 'White'],
#  486: ['Cream', 'White'],
#  487: ['Cream', 'White'],
#  488: ['Cream', 'White'],
#  489: ['Cream', 'White'],
#  490: ['Zebra'],
#  491: ['Zebra'],
#  492: ['Zebra'],
#  493: ['Zebra'],
#  494: ['Zebra'],
#  495: ['Zebra'],
#  496: ['White', 'Chicago'],
#  497: ['White', 'Chicago'],
#  498: ['White', 'Chicago'],
#  499: ['White'],
#  500: ['White'],
#  501: ['White'],
#  502: ['White'],
#  503: ['White'],
#  504: ['Black', 'Copper'],
#  505: ['Black', 'Green'],
#  506: ['Black', 'Red'],
#  507: ['Black', 'Red'],
#  508: ['Black', 'White'],
#  509: ['Cream', 'White'],
#  510: ['Cream', 'White'],
#  511: ['Cream', 'White'],
#  512: ['Cream', 'White'],
#  513: ['Cream', 'White'],
#  514: ['Zebra'],
#  515: ['Zebra'],
#  516: ['Zebra'],
#  517: ['Zebra'],
#  518: ['Zebra'],
#  519: ['Zebra'],
#  520: ['White', 'Chicago'],
#  521: ['White'],
#  522: ['White'],
#  523: ['White'],
#  524: ['White'],
#  525: ['White'],
#  526: ['White'],
#  527: ['Beluga'],
#  528: ['Black', 'Red'],
#  529: ['Black', 'White'],
#  530: ['Cream', 'White'],
#  531: ['Cream', 'White'],
#  532: ['Cream', 'White'],
#  533: ['Zebra'],
#  534: ['Zebra'],
#  535: ['Zebra'],
#  536: ['Zebra'],
#  537: ['Zebra'],
#  538: ['Zebra'],
#  539: ['White', 'Chicago'],
#  540: ['White', 'Chicago'],
#  541: ['White'],
#  542: ['White'],
#  543: ['White'],
#  544: ['White'],
#  545: ['Beluga'],
#  546: ['Black', 'Copper'],
#  547: ['Black', 'Red'],
#  548: ['Black', 'Red'],
#  549: ['Black', 'White'],
#  550: ['Black', 'White'],
#  551: ['Cream', 'White'],
#  552: ['Cream', 'White'],
#  553: ['Cream', 'White'],
#  554: ['Cream', 'White'],
#  555: ['Cream', 'White'],
#  556: ['Zebra'],
#  557: ['Zebra'],
#  558: ['Zebra'],
#  559: ['Zebra'],
#  560: ['Zebra'],
#  561: ['White', 'Chicago'],
#  562: ['White'],
#  563: ['White'],
#  564: ['Tan'],
#  565: ['Black'],
#  566: ['Turtledove'],
#  567: ['Beluga'],
#  568: ['Beluga'],
#  569: ['Black', 'Red'],
#  570: ['Black', 'Red'],
#  571: ['Black', 'Red'],
#  572: ['Cream', 'White'],
#  573: ['Cream', 'White'],
#  574: ['Cream', 'White'],
#  575: ['Cream', 'White'],
#  576: ['Zebra'],
#  577: ['Zebra'],
#  578: ['Zebra'],
#  579: ['Zebra'],
#  580: ['Zebra'],
#  581: ['Zebra'],
#  582: ['Zebra'],
#  583: ['Zebra'],
#  584: ['White', 'Chicago'],
#  585: ['White'],
#  586: ['White'],
#  587: ['White'],
#  588: ['Moonrock'],
#  589: ['Beluga'],
#  590: ['Black', 'Copper'],
#  591: ['Black', 'Red'],
#  592: ['Black', 'Red'],
#  593: ['Black', 'White'],
#  594: ['Black', 'White'],
#  595: ['Cream', 'White'],
#  596: ['Cream', 'White'],
#  597: ['Cream', 'White'],
#  598: ['Cream', 'White'],
#  599: ['Cream', 'White'],
#  600: ['Zebra'],
#  601: ['Zebra'],
#  602: ['Zebra'],
#  603: ['Zebra'],
#  604: ['Zebra'],
#  605: ['Zebra'],
#  606: ['Zebra'],
#  607: ['White', 'Chicago'],
#  608: ['White'],
#  609: ['White'],
#  610: ['White'],
#  611: ['White'],
#  612: ['White'],
#  613: ['White'],
#  614: ['Beluga'],
#  615: ['Black', 'Red'],
#  616: ['Black', 'Red'],
#  617: ['Black', 'Red'],
#  618: ['Black', 'White'],
#  619: ['Cream', 'White'],
#  620: ['Cream', 'White'],
#  621: ['Cream', 'White'],
#  622: ['Cream', 'White'],
#  623: ['Cream', 'White'],
#  624: ['Cream', 'White'],
#  625: ['Zebra'],
#  626: ['Zebra'],
#  627: ['Zebra'],
#  628: ['Zebra'],
#  629: ['Zebra'],
#  630: ['Zebra'],
#  631: ['Zebra'],
#  632: ['White', 'Chicago'],
#  633: ['White', 'Chicago'],
#  634: ['White'],
#  635: ['White'],
#  636: ['White'],
#  637: ['White'],
#  638: ['White'],
#  639: ['White'],
#  640: ['White'],
#  641: ['Black', 'Green'],
#  642: ['Black', 'Red'],
#  643: ['Black', 'Red'],
#  644: ['Black', 'White'],
#  645: ['Cream', 'White'],
#  646: ['Cream', 'White'],
#  647: ['Cream', 'White'],
#  648: ['Zebra'],
#  649: ['Zebra'],
#  650: ['Zebra'],
#  651: ['Zebra'],
#  652: ['White', 'Chicago'],
#  653: ['White'],
#  654: ['White'],
#  655: ['White'],
#  656: ['Black', 'Copper'],
#  657: ['Black', 'Red'],
#  658: ['Black', 'Red'],
#  659: ['Black', 'White'],
#  660: ['Cream', 'White'],
#  661: ['Cream', 'White'],
#  662: ['Cream', 'White'],
#  663: ['Cream', 'White'],
#  664: ['Cream', 'White'],
#  665: ['Zebra'],
#  666: ['Zebra'],
#  667: ['Zebra'],
#  668: ['Zebra'],
#  669: ['Zebra'],
#  670: ['Zebra'],
#  671: ['Zebra'],
#  672: ['Zebra'],
#  673: ['White', 'Chicago'],
#  674: ['White', 'Chicago'],
#  675: ['White'],
#  676: ['White'],
#  677: ['White'],
#  678: ['White'],
#  679: ['White'],
#  680: ['White'],
#  681: ['White'],
#  682: ['Black', 'Red'],
#  683: ['Black', 'Red'],
#  684: ['Black', 'White'],
#  685: ['Cream', 'White'],
#  686: ['Cream', 'White'],
#  687: ['Cream', 'White'],
#  688: ['Cream', 'White'],
#  689: ['Zebra'],
#  690: ['Zebra'],
#  691: ['Zebra'],
#  692: ['Zebra'],
#  693: ['White', 'Chicago'],
#  694: ['White'],
#  695: ['White'],
#  696: ['White'],
#  697: ['Beluga'],
#  698: ['Black', 'Red'],
#  699: ['Black', 'Red'],
#  700: ['Black', 'White'],
#  701: ['Cream', 'White'],
#  702: ['Cream', 'White'],
#  703: ['Cream', 'White'],
#  704: ['Cream', 'White'],
#  705: ['Cream', 'White'],
#  706: ['Zebra'],
#  707: ['Zebra'],
#  708: ['Zebra'],
#  709: ['White', 'Chicago'],
#  710: ['White'],
#  711: ['White'],
#  712: ['Beluga'],
#  713: ['Black', 'Red'],
#  714: ['Black', 'Red'],
#  715: ['Black', 'Red'],
#  716: ['Black', 'Red'],
#  717: ['Black', 'White'],
#  718: ['Black', 'White'],
#  719: ['Cream', 'White'],
#  720: ['Cream', 'White'],
#  721: ['Cream', 'White'],
#  722: ['Cream', 'White'],
#  723: ['Cream', 'White'],
#  724: ['Zebra'],
#  725: ['Zebra'],
#  726: ['Zebra'],
#  727: ['Zebra'],
#  728: ['Zebra'],
#  729: ['Zebra'],
#  730: ['Zebra'],
#  731: ['White', 'Chicago'],
#  732: ['White', 'Chicago'],
#  733: ['White'],
#  734: ['White'],
#  735: ['Beluga'],
#  736: ['Beluga'],
#  737: ['Black', 'Green'],
#  738: ['Black', 'Red'],
#  739: ['Black', 'Red'],
#  740: ['Black', 'Red'],
#  741: ['Black', 'Red'],
#  742: ['Black', 'White'],
#  743: ['Cream', 'White'],
#  744: ['Cream', 'White'],
#  745: ['Cream', 'White'],
#  746: ['Cream', 'White'],
#  747: ['Zebra'],
#  748: ['Zebra'],
#  749: ['Zebra'],
#  750: ['Zebra'],
#  751: ['Zebra'],
#  752: ['Zebra'],
#  753: ['Zebra'],
#  754: ['Zebra'],
#  755: ['Zebra'],
#  756: ['Zebra'],
#  757: ['White', 'Chicago'],
#  758: ['White', 'Chicago'],
#  759: ['White'],
#  760: ['White'],
#  761: ['White'],
#  762: ['White'],
#  763: ['White'],
#  764: ['Moonrock'],
#  765: ['Beluga'],
#  766: ['Black', 'Red'],
#  767: ['Black', 'Red'],
#  768: ['Black', 'Red'],
#  769: ['Black', 'Red'],
#  770: ['Black', 'Red'],
#  771: ['Black', 'White'],
#  772: ['Cream', 'White'],
#  773: ['Cream', 'White'],
#  774: ['Cream', 'White'],
#  775: ['Cream', 'White'],
#  776: ['Zebra'],
#  777: ['Zebra'],
#  778: ['Zebra'],
#  779: ['Zebra'],
#  780: ['Zebra'],
#  781: ['Zebra'],
#  782: ['White', 'Chicago'],
#  783: ['White'],
#  784: ['White'],
#  785: ['White'],
#  786: ['White'],
#  787: ['Black'],
#  788: ['Beluga'],
#  789: ['Black', 'Red'],
#  790: ['Black', 'Red'],
#  791: ['Black', 'Red'],
#  792: ['Black', 'White'],
#  793: ['Cream', 'White'],
#  794: ['Cream', 'White'],
#  795: ['Cream', 'White'],
#  796: ['Cream', 'White'],
#  797: ['Zebra'],
#  798: ['Zebra'],
#  799: ['Zebra'],
#  800: ['Zebra'],
#  801: ['White'],
#  802: ['Beluga'],
#  803: ['Beluga'],
#  804: ['Black', 'Red'],
#  805: ['Black', 'Red'],
#  806: ['Black', 'White'],
#  807: ['Cream', 'White'],
#  808: ['Cream', 'White'],
#  809: ['Cream', 'White'],
#  810: ['Cream', 'White'],
#  811: ['Zebra'],
#  812: ['Zebra'],
#  813: ['Zebra'],
#  814: ['Zebra'],
#  815: ['White', 'Chicago'],
#  816: ['White'],
#  817: ['White'],
#  818: ['White'],
#  819: ['Beluga'],
#  820: ['Black', 'Copper'],
#  821: ['Black', 'Red'],
#  822: ['Black', 'White'],
#  823: ['Cream', 'White'],
#  824: ['Cream', 'White'],
#  825: ['Cream', 'White'],
#  826: ['Cream', 'White'],
#  827: ['Cream', 'White'],
#  828: ['Zebra'],
#  829: ['Zebra'],
#  830: ['Zebra'],
#  831: ['Zebra'],
#  832: ['Zebra'],
#  833: ['White'],
#  834: ['White'],
#  835: ['Black'],
#  836: ['Beluga'],
#  837: ['Black', 'Red'],
#  838: ['Black', 'Red'],
#  839: ['Black', 'White'],
#  840: ['Cream', 'White'],
#  841: ['Cream', 'White'],
#  842: ['Cream', 'White'],
#  843: ['Zebra'],
#  844: ['Zebra'],
#  845: ['Zebra'],
#  846: ['Zebra'],
#  847: ['Zebra'],
#  848: ['Zebra'],
#  849: ['White', 'Chicago'],
#  850: ['White'],
#  851: ['White'],
#  852: ['White'],
#  853: ['Black', 'Red'],
#  854: ['Black', 'Red'],
#  855: ['Cream', 'White'],
#  856: ['Cream', 'White'],
#  857: ['Cream', 'White'],
#  858: ['Cream', 'White'],
#  859: ['Cream', 'White'],
#  860: ['Cream', 'White'],
#  861: ['Zebra'],
#  862: ['Zebra'],
#  863: ['Zebra'],
#  864: ['Zebra'],
#  865: ['White', 'Chicago'],
#  866: ['White'],
#  867: ['Black'],
#  868: ['Beluga'],
#  869: ['Black', 'Copper'],
#  870: ['Black', 'Green'],
#  871: ['Black', 'Red'],
#  872: ['Black', 'Red'],
#  873: ['Black', 'Red'],
#  874: ['Black', 'White'],
#  875: ['Cream', 'White'],
#  876: ['Cream', 'White'],
#  877: ['Cream', 'White'],
#  878: ['Zebra'],
#  879: ['Zebra'],
#  880: ['Zebra'],
#  881: ['Zebra'],
#  882: ['Zebra'],
#  883: ['Zebra'],
#  884: ['White', 'Chicago'],
#  885: ['White'],
#  886: ['White'],
#  887: ['White'],
#  888: ['Beluga'],
#  889: ['Black', 'Red'],
#  890: ['Black', 'Red'],
#  891: ['Black', 'White'],
#  892: ['Cream', 'White'],
#  893: ['Cream', 'White'],
#  894: ['Cream', 'White'],
#  895: ['Cream', 'White'],
#  896: ['Zebra'],
#  897: ['Zebra'],
#  898: ['Zebra'],
#  899: ['Zebra'],
#  900: ['Zebra'],
#  901: ['White'],
#  902: ['White'],
#  903: ['Moonrock'],
#  904: ['Beluga'],
#  905: ['Black', 'Copper'],
#  906: ['Black', 'Red'],
#  907: ['Black', 'Red'],
#  908: ['Black', 'Red'],
#  909: ['Black', 'White'],
#  910: ['Cream', 'White'],
#  911: ['Cream', 'White'],
#  912: ['Cream', 'White'],
#  913: ['Zebra'],
#  914: ['Zebra'],
#  915: ['Zebra'],
#  916: ['Zebra'],
#  917: ['Zebra'],
#  918: ['Zebra'],
#  919: ['Moonrock'],
#  920: ['Tan'],
#  921: ['Tan'],
#  922: ['Black'],
#  923: ['Black'],
#  924: ['Black'],
#  925: ['Black'],
#  926: ['Turtledove'],
#  927: ['Turtledove'],
#  928: ['Beluga'],
#  929: ['Beluga'],
#  930: ['Beluga'],
#  931: ['Beluga'],
#  932: ['Beluga'],
#  933: ['Beluga'],
#  934: ['Beluga'],
#  935: ['Beluga'],
#  936: ['Beluga'],
#  937: ['Beluga'],
#  938: ['Black', 'Copper'],
#  939: ['Black', 'Copper'],
#  940: ['Black', 'Green'],
#  941: ['Black', 'Green'],
#  942: ['Black', 'Green'],
#  943: ['Black', 'Green'],
#  944: ['Black', 'Red'],
#  945: ['Black', 'Red'],
#  946: ['Black', 'Red'],
#  947: ['Black', 'Red'],
#  948: ['Black', 'Red'],
#  949: ['Black', 'Red'],
#  950: ['Black', 'Red'],
#  951: ['Black', 'Red'],
#  952: ['Black', 'Red'],
#  953: ['Black', 'Red'],
#  954: ['Black', 'Red'],
#  955: ['Black', 'Red'],
#  956: ['Black', 'Red'],
#  957: ['Black', 'Red'],
#  958: ['Black', 'Red'],
#  959: ['Black', 'Red'],
#  960: ['Black', 'Red'],
#  961: ['Black', 'Red'],
#  962: ['Black', 'Red'],
#  963: ['Black', 'Red'],
#  964: ['Black', 'Red'],
#  965: ['Black', 'Red'],
#  966: ['Black', 'White'],
#  967: ['Black', 'White'],
#  968: ['Black', 'White'],
#  969: ['Black', 'White'],
#  970: ['Black', 'White'],
#  971: ['Black', 'White'],
#  972: ['Black', 'White'],
#  973: ['Cream', 'White'],
#  974: ['Cream', 'White'],
#  975: ['Cream', 'White'],
#  976: ['Cream', 'White'],
#  977: ['Cream', 'White'],
#  978: ['Cream', 'White'],
#  979: ['Cream', 'White'],
#  980: ['Cream', 'White'],
#  981: ['Cream', 'White'],
#  982: ['Cream', 'White'],
#  983: ['Cream', 'White'],
#  984: ['Cream', 'White'],
#  985: ['Cream', 'White'],
#  986: ['Cream', 'White'],
#  987: ['Cream', 'White'],
#  988: ['Cream', 'White'],
#  989: ['Cream', 'White'],
#  990: ['Cream', 'White'],
#  991: ['Cream', 'White'],
#  992: ['Cream', 'White'],
#  993: ['Cream', 'White'],
#  994: ['Cream', 'White'],
#  995: ['Cream', 'White'],
#  996: ['Cream', 'White'],
#  997: ['Cream', 'White'],
#  998: ['Cream', 'White'],
#  999: ['Zebra'],
#  ...}

# %%
shoes = shoes.with_column('Colors', shoedict.values())
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\datascience\tables.py:920: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   values = np.array(tuple(values))

# %%
shoes.show(1000)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Order Date</th> <th>Brand</th> <th>Sneaker Name</th> <th>Sale Price</th> <th>Retail Price</th> <th>Release Date</th> <th>Shoe Size</th> <th>Buyer Region</th> <th>Colors</th> <th>Version</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-Low-V2-Beluga         </td> <td>$1,097    </td> <td>$220        </td> <td>9/24/16     </td> <td>11       </td> <td>California          </td> <td>['Beluga']          </td> <td>V2      </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Copper  </td> <td>$685      </td> <td>$220        </td> <td>11/23/16    </td> <td>11       </td> <td>California          </td> <td>['Black', 'Copper'] </td> <td>V2      </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Green   </td> <td>$690      </td> <td>$220        </td> <td>11/23/16    </td> <td>11       </td> <td>California          </td> <td>['Black', 'Green']  </td> <td>V2      </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red     </td> <td>$1,075    </td> <td>$220        </td> <td>11/23/16    </td> <td>11.5     </td> <td>Kentucky            </td> <td>['Black', 'Red']    </td> <td>V2      </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017</td> <td>$828      </td> <td>$220        </td> <td>2/11/17     </td> <td>11       </td> <td>Rhode Island        </td> <td>['Black', 'Red']    </td> <td>V2      </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2
17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017</td> <td>$740      </td> <td>$220        </td> <td>2/11/17     </td> <td>9        </td> <td>New York            </td> <td>['Black', 'Red']    </td> <td>V2      </td>
#         </tr>
#         <tr>
#             <td>9/2/17    </td> <td

# %%
versions = ['V1', 'V2', 'V3', '90', '1', '91', '92', '93', '94', '95', '96', '97', '98', '99',"VaporMax", 'Presto', 'Blazer',"Hyperdunk", 'Zoom']
versiondict = {}
counter = 0
for shoe in shoes.column(2):
    colors_list = []
    shoe_list = shoe.split("-")
    for char in shoe_list:
        if char in versions:
            colors_list.append(char)
        if char == "Yeezy" and 'V2' not in shoe_list:
            colors_list.append('V1')
        
    versiondict[counter] = colors_list
    counter += 1

# %%
versiondict
# Out:
# {0: ['V2'],
#  1: ['V2'],
#  2: ['V2'],
#  3: ['V2'],
#  4: ['V2'],
#  5: ['V2'],
#  6: ['V2'],
#  7: ['V2'],
#  8: ['V2'],
#  9: ['V2'],
#  10: ['V2'],
#  11: ['V2'],
#  12: ['V2'],
#  13: ['V2'],
#  14: ['V2'],
#  15: ['V2'],
#  16: ['V2'],
#  17: ['V2'],
#  18: ['V2'],
#  19: ['V2'],
#  20: ['V2'],
#  21: ['V2'],
#  22: ['V2'],
#  23: ['V2'],
#  24: ['V2'],
#  25: ['V2'],
#  26: ['V2'],
#  27: ['V2'],
#  28: ['V2'],
#  29: ['V2'],
#  30: ['V2'],
#  31: ['V2'],
#  32: ['V2'],
#  33: ['V2'],
#  34: ['V2'],
#  35: ['V2'],
#  36: ['V2'],
#  37: ['V2'],
#  38: ['V2'],
#  39: ['V2'],
#  40: ['V2'],
#  41: ['V2'],
#  42: ['V2'],
#  43: ['V2'],
#  44: ['V2'],
#  45: ['V2'],
#  46: ['V2'],
#  47: ['V2'],
#  48: ['V2'],
#  49: ['V2'],
#  50: ['V2'],
#  51: ['V2'],
#  52: ['V2'],
#  53: ['V2'],
#  54: ['V2'],
#  55: ['V2'],
#  56: ['V2'],
#  57: ['V2'],
#  58: ['V2'],
#  59: ['V2'],
#  60: ['V2'],
#  61: ['V2'],
#  62: ['V2'],
#  63: ['V2'],
#  64: ['V2'],
#  65: ['V2'],
#  66: ['V2'],
#  67: ['V2'],
#  68: ['V2'],
#  69: ['V2'],
#  70: ['V2'],
#  71: ['V2'],
#  72: ['V2'],
#  73: ['V2'],
#  74: ['V2'],
#  75: ['V2'],
#  76: ['V2'],
#  77: ['V2'],
#  78: ['V2'],
#  79: ['V2'],
#  80: ['V2'],
#  81: ['V2'],
#  82: ['V2'],
#  83: ['V2'],
#  84: ['V2'],
#  85: ['V2'],
#  86: ['V2'],
#  87: ['V2'],
#  88: ['V2'],
#  89: ['V2'],
#  90: ['V2'],
#  91: ['V2'],
#  92: ['V2'],
#  93: ['V2'],
#  94: ['V2'],
#  95: ['V2'],
#  96: ['V2'],
#  97: ['V2'],
#  98: ['V2'],
#  99: ['V2'],
#  100: ['V2'],
#  101: ['V2'],
#  102: ['V2'],
#  103: ['V2'],
#  104: ['V2'],
#  105: ['V2'],
#  106: ['V2'],
#  107: ['V2'],
#  108: ['V2'],
#  109: ['V2'],
#  110: ['V2'],
#  111: ['V2'],
#  112: ['V1'],
#  113: ['V2'],
#  114: ['V2'],
#  115: ['V2'],
#  116: ['V2'],
#  117: ['V2'],
#  118: ['V2'],
#  119: ['V2'],
#  120: ['V2'],
#  121: ['V2'],
#  122: ['V2'],
#  123: ['V2'],
#  124: ['V2'],
#  125: ['V2'],
#  126: ['V2'],
#  127: ['V2'],
#  128: ['90'],
#  129: ['90'],
#  130: ['Presto'],
#  131: ['Presto'],
#  132: ['VaporMax'],
#  133: ['V2'],
#  134: ['V2'],
#  135: ['V2'],
#  136: ['V2'],
#  137: ['V2'],
#  138: ['V2'],
#  139: ['V2'],
#  140: ['V2'],
#  141: ['V2'],
#  142: ['V2'],
#  143: ['V2'],
#  144: ['V2'],
#  145: ['V2'],
#  146: ['V2'],
#  147: ['V2'],
#  148: ['V2'],
#  149: ['1'],
#  150: ['1'],
#  151: ['90'],
#  152: ['Presto'],
#  153: ['VaporMax'],
#  154: ['Blazer'],
#  155: ['Blazer'],
#  156: ['V1'],
#  157: ['V2'],
#  158: ['V2'],
#  159: ['V2'],
#  160: ['V2'],
#  161: ['V2'],
#  162: ['V2'],
#  163: ['V2'],
#  164: ['V2'],
#  165: ['V2'],
#  166: ['V2'],
#  167: ['V2'],
#  168: ['V2'],
#  169: ['V2'],
#  170: ['V2'],
#  171: ['V2'],
#  172: ['1'],
#  173: ['1'],
#  174: ['90'],
#  175: ['90'],
#  176: ['90'],
#  177: ['Presto'],
#  178: ['Blazer'],
#  179: ['V1'],
#  180: ['V2'],
#  181: ['V2'],
#  182: ['V2'],
#  183: ['V2'],
#  184: ['V2'],
#  185: ['V2'],
#  186: ['V2'],
#  187: ['V2'],
#  188: ['V2'],
#  189: ['V2'],
#  190: ['V2'],
#  191: ['V2'],
#  192: ['V2'],
#  193: ['V2'],
#  194: ['1'],
#  195: ['90'],
#  196: ['90'],
#  197: ['Presto'],
#  198: ['Presto'],
#  199: ['Presto'],
#  200: ['Presto'],
#  201: ['VaporMax'],
#  202: ['Blazer'],
#  203: ['Blazer'],
#  204: ['V1'],
#  205: ['V2'],
#  206: ['V2'],
#  207: ['V2'],
#  208: ['V2'],
#  209: ['V2'],
#  210: ['V2'],
#  211: ['V2'],
#  212: ['V2'],
#  213: ['V2'],
#  214: ['V2'],
#  215: ['V2'],
#  216: ['V2'],
#  217: ['V2'],
#  218: ['V2'],
#  219: ['V2'],
#  220: ['V2'],
#  221: ['V2'],
#  222: ['1'],
#  223: ['90'],
#  224: ['90'],
#  225: ['Presto'],
#  226: ['Presto'],
#  227: ['Presto'],
#  228: ['VaporMax'],
#  229: ['VaporMax'],
#  230: ['VaporMax'],
#  231: ['Blazer'],
#  232: ['Blazer'],
#  233: ['Blazer'],
#  234: ['Blazer'],
#  235: ['V1'],
#  236: ['V2'],
#  237: ['V2'],
#  238: ['V2'],
#  239: ['V2'],
#  240: ['V2'],
#  241: ['V2'],
#  242: ['V2'],
#  243: ['V2'],
#  244: ['V2'],
#  245: ['V2'],
#  246: ['V2'],
#  247: ['V2'],
#  248: ['V2'],
#  249: ['V2'],
#  250: ['V2'],
#  251: ['V2'],
#  252: ['V2'],
#  253: ['V2'],
#  254: ['V2'],
#  255: ['V2'],
#  256: ['V2'],
#  257: ['V2'],
#  258: ['V2'],
#  259: ['1'],
#  260: ['90'],
#  261: ['90'],
#  262: ['90'],
#  263: ['Presto'],
#  264: ['VaporMax'],
#  265: ['VaporMax'],
#  266: ['Blazer'],
#  267: ['Blazer'],
#  268: ['V2'],
#  269: ['V2'],
#  270: ['V2'],
#  271: ['V2'],
#  272: ['V2'],
#  273: ['V2'],
#  274: ['V2'],
#  275: ['V2'],
#  276: ['V2'],
#  277: ['V2'],
#  278: ['V2'],
#  279: ['V2'],
#  280: ['V2'],
#  281: ['V2'],
#  282: ['V2'],
#  283: ['V2'],
#  284: ['V2'],
#  285: ['V2'],
#  286: ['V2'],
#  287: ['1'],
#  288: ['1'],
#  289: ['1'],
#  290: ['90'],
#  291: ['Presto'],
#  292: ['Presto'],
#  293: ['VaporMax'],
#  294: ['VaporMax'],
#  295: ['Blazer'],
#  296: ['Blazer'],
#  297: ['V1'],
#  298: ['V1'],
#  299: ['V2'],
#  300: ['V2'],
#  301: ['V2'],
#  302: ['V2'],
#  303: ['V2'],
#  304: ['V2'],
#  305: ['V2'],
#  306: ['V2'],
#  307: ['V2'],
#  308: ['V2'],
#  309: ['V2'],
#  310: ['V2'],
#  311: ['V2'],
#  312: ['V2'],
#  313: ['V2'],
#  314: ['V2'],
#  315: ['V2'],
#  316: ['V2'],
#  317: ['1'],
#  318: ['1'],
#  319: ['1'],
#  320: ['90'],
#  321: ['Presto'],
#  322: ['VaporMax'],
#  323: ['Blazer'],
#  324: ['Blazer'],
#  325: ['Blazer'],
#  326: ['V1'],
#  327: ['V2'],
#  328: ['V2'],
#  329: ['V2'],
#  330: ['V2'],
#  331: ['V2'],
#  332: ['V2'],
#  333: ['V2'],
#  334: ['V2'],
#  335: ['V2'],
#  336: ['V2'],
#  337: ['V2'],
#  338: ['V2'],
#  339: ['V2'],
#  340: ['V2'],
#  341: ['V2'],
#  342: ['V2'],
#  343: ['1'],
#  344: ['1'],
#  345: ['1'],
#  346: ['1'],
#  347: ['90'],
#  348: ['Presto'],
#  349: ['Presto'],
#  350: ['VaporMax'],
#  351: ['Blazer'],
#  352: ['V2'],
#  353: ['V2'],
#  354: ['V2'],
#  355: ['V2'],
#  356: ['V2'],
#  357: ['V2'],
#  358: ['V2'],
#  359: ['V2'],
#  360: ['V2'],
#  361: ['V2'],
#  362: ['V2'],
#  363: ['V2'],
#  364: ['V2'],
#  365: ['V2'],
#  366: ['1'],
#  367: ['1'],
#  368: ['90'],
#  369: ['Presto'],
#  370: ['Presto'],
#  371: ['VaporMax'],
#  372: ['VaporMax'],
#  373: ['V2'],
#  374: ['V2'],
#  375: ['V2'],
#  376: ['V2'],
#  377: ['V2'],
#  378: ['V2'],
#  379: ['V2'],
#  380: ['V2'],
#  381: ['V2'],
#  382: ['V2'],
#  383: ['V2'],
#  384: ['V2'],
#  385: ['V2'],
#  386: ['V2'],
#  387: ['1'],
#  388: ['Presto'],
#  389: ['Presto'],
#  390: ['Presto'],
#  391: ['VaporMax'],
#  392: ['VaporMax'],
#  393: ['Blazer'],
#  394: ['V2'],
#  395: ['V2'],
#  396: ['V2'],
#  397: ['V2'],
#  398: ['V2'],
#  399: ['V2'],
#  400: ['V2'],
#  401: ['V2'],
#  402: ['V2'],
#  403: ['V2'],
#  404: ['V2'],
#  405: ['V2'],
#  406: ['V2'],
#  407: ['V2'],
#  408: ['V2'],
#  409: ['V2'],
#  410: ['V2'],
#  411: ['V2'],
#  412: ['V2'],
#  413: ['1'],
#  414: ['1'],
#  415: ['90'],
#  416: ['Presto'],
#  417: ['Presto'],
#  418: ['VaporMax'],
#  419: ['VaporMax'],
#  420: ['Blazer'],
#  421: ['V2'],
#  422: ['V2'],
#  423: ['V2'],
#  424: ['V2'],
#  425: ['V2'],
#  426: ['V2'],
#  427: ['V2'],
#  428: ['V2'],
#  429: ['V2'],
#  430: ['V2'],
#  431: ['V2'],
#  432: ['V2'],
#  433: ['V2'],
#  434: ['V2'],
#  435: ['V2'],
#  436: ['1'],
#  437: ['1'],
#  438: ['90'],
#  439: ['Presto'],
#  440: ['Presto'],
#  441: ['VaporMax'],
#  442: ['VaporMax'],
#  443: ['Blazer'],
#  444: ['Blazer'],
#  445: ['V1'],
#  446: ['V2'],
#  447: ['V2'],
#  448: ['V2'],
#  449: ['V2'],
#  450: ['V2'],
#  451: ['V2'],
#  452: ['V2'],
#  453: ['V2'],
#  454: ['V2'],
#  455: ['V2'],
#  456: ['V2'],
#  457: ['V2'],
#  458: ['V2'],
#  459: ['V2'],
#  460: ['V2'],
#  461: ['V2'],
#  462: ['V2'],
#  463: ['V2'],
#  464: ['V2'],
#  465: ['1'],
#  466: ['1'],
#  467: ['90'],
#  468: ['90'],
#  469: ['Presto'],
#  470: ['VaporMax'],
#  471: ['VaporMax'],
#  472: ['VaporMax'],
#  473: ['VaporMax'],
#  474: ['Blazer'],
#  475: ['Blazer'],
#  476: ['V1'],
#  477: ['V2'],
#  478: ['V2'],
#  479: ['V2'],
#  480: ['V2'],
#  481: ['V2'],
#  482: ['V2'],
#  483: ['V2'],
#  484: ['V2'],
#  485: ['V2'],
#  486: ['V2'],
#  487: ['V2'],
#  488: ['V2'],
#  489: ['V2'],
#  490: ['V2'],
#  491: ['V2'],
#  492: ['V2'],
#  493: ['V2'],
#  494: ['V2'],
#  495: ['V2'],
#  496: ['1'],
#  497: ['1'],
#  498: ['1'],
#  499: ['90'],
#  500: ['Presto'],
#  501: ['Presto'],
#  502: ['VaporMax'],
#  503: ['Blazer'],
#  504: ['V2'],
#  505: ['V2'],
#  506: ['V2'],
#  507: ['V2'],
#  508: ['V2'],
#  509: ['V2'],
#  510: ['V2'],
#  511: ['V2'],
#  512: ['V2'],
#  513: ['V2'],
#  514: ['V2'],
#  515: ['V2'],
#  516: ['V2'],
#  517: ['V2'],
#  518: ['V2'],
#  519: ['V2'],
#  520: ['1'],
#  521: ['90'],
#  522: ['90'],
#  523: ['Presto'],
#  524: ['Presto'],
#  525: ['Presto'],
#  526: ['Blazer'],
#  527: ['V2'],
#  528: ['V2'],
#  529: ['V2'],
#  530: ['V2'],
#  531: ['V2'],
#  532: ['V2'],
#  533: ['V2'],
#  534: ['V2'],
#  535: ['V2'],
#  536: ['V2'],
#  537: ['V2'],
#  538: ['V2'],
#  539: ['1'],
#  540: ['1'],
#  541: ['90'],
#  542: ['90'],
#  543: ['Presto'],
#  544: ['Presto'],
#  545: ['V2'],
#  546: ['V2'],
#  547: ['V2'],
#  548: ['V2'],
#  549: ['V2'],
#  550: ['V2'],
#  551: ['V2'],
#  552: ['V2'],
#  553: ['V2'],
#  554: ['V2'],
#  555: ['V2'],
#  556: ['V2'],
#  557: ['V2'],
#  558: ['V2'],
#  559: ['V2'],
#  560: ['V2'],
#  561: ['1'],
#  562: ['VaporMax'],
#  563: ['Blazer'],
#  564: ['V1'],
#  565: ['V1'],
#  566: ['V1'],
#  567: ['V2'],
#  568: ['V2'],
#  569: ['V2'],
#  570: ['V2'],
#  571: ['V2'],
#  572: ['V2'],
#  573: ['V2'],
#  574: ['V2'],
#  575: ['V2'],
#  576: ['V2'],
#  577: ['V2'],
#  578: ['V2'],
#  579: ['V2'],
#  580: ['V2'],
#  581: ['V2'],
#  582: ['V2'],
#  583: ['V2'],
#  584: ['1'],
#  585: ['90'],
#  586: ['Presto'],
#  587: ['Blazer'],
#  588: ['V1'],
#  589: ['V2'],
#  590: ['V2'],
#  591: ['V2'],
#  592: ['V2'],
#  593: ['V2'],
#  594: ['V2'],
#  595: ['V2'],
#  596: ['V2'],
#  597: ['V2'],
#  598: ['V2'],
#  599: ['V2'],
#  600: ['V2'],
#  601: ['V2'],
#  602: ['V2'],
#  603: ['V2'],
#  604: ['V2'],
#  605: ['V2'],
#  606: ['V2'],
#  607: ['1'],
#  608: ['90'],
#  609: ['Presto'],
#  610: ['VaporMax'],
#  611: ['VaporMax'],
#  612: ['VaporMax'],
#  613: ['Blazer'],
#  614: ['V2'],
#  615: ['V2'],
#  616: ['V2'],
#  617: ['V2'],
#  618: ['V2'],
#  619: ['V2'],
#  620: ['V2'],
#  621: ['V2'],
#  622: ['V2'],
#  623: ['V2'],
#  624: ['V2'],
#  625: ['V2'],
#  626: ['V2'],
#  627: ['V2'],
#  628: ['V2'],
#  629: ['V2'],
#  630: ['V2'],
#  631: ['V2'],
#  632: ['1'],
#  633: ['1'],
#  634: ['90'],
#  635: ['90'],
#  636: ['Presto'],
#  637: ['Presto'],
#  638: ['VaporMax'],
#  639: ['Blazer'],
#  640: ['Blazer'],
#  641: ['V2'],
#  642: ['V2'],
#  643: ['V2'],
#  644: ['V2'],
#  645: ['V2'],
#  646: ['V2'],
#  647: ['V2'],
#  648: ['V2'],
#  649: ['V2'],
#  650: ['V2'],
#  651: ['V2'],
#  652: ['1'],
#  653: ['90'],
#  654: ['Presto'],
#  655: ['Presto'],
#  656: ['V2'],
#  657: ['V2'],
#  658: ['V2'],
#  659: ['V2'],
#  660: ['V2'],
#  661: ['V2'],
#  662: ['V2'],
#  663: ['V2'],
#  664: ['V2'],
#  665: ['V2'],
#  666: ['V2'],
#  667: ['V2'],
#  668: ['V2'],
#  669: ['V2'],
#  670: ['V2'],
#  671: ['V2'],
#  672: ['V2'],
#  673: ['1'],
#  674: ['1'],
#  675: ['90'],
#  676: ['90'],
#  677: ['Presto'],
#  678: ['Presto'],
#  679: ['VaporMax'],
#  680: ['VaporMax'],
#  681: ['Blazer'],
#  682: ['V2'],
#  683: ['V2'],
#  684: ['V2'],
#  685: ['V2'],
#  686: ['V2'],
#  687: ['V2'],
#  688: ['V2'],
#  689: ['V2'],
#  690: ['V2'],
#  691: ['V2'],
#  692: ['V2'],
#  693: ['1'],
#  694: ['90'],
#  695: ['VaporMax'],
#  696: ['Blazer'],
#  697: ['V2'],
#  698: ['V2'],
#  699: ['V2'],
#  700: ['V2'],
#  701: ['V2'],
#  702: ['V2'],
#  703: ['V2'],
#  704: ['V2'],
#  705: ['V2'],
#  706: ['V2'],
#  707: ['V2'],
#  708: ['V2'],
#  709: ['1'],
#  710: ['Presto'],
#  711: ['Blazer'],
#  712: ['V2'],
#  713: ['V2'],
#  714: ['V2'],
#  715: ['V2'],
#  716: ['V2'],
#  717: ['V2'],
#  718: ['V2'],
#  719: ['V2'],
#  720: ['V2'],
#  721: ['V2'],
#  722: ['V2'],
#  723: ['V2'],
#  724: ['V2'],
#  725: ['V2'],
#  726: ['V2'],
#  727: ['V2'],
#  728: ['V2'],
#  729: ['V2'],
#  730: ['V2'],
#  731: ['1'],
#  732: ['1'],
#  733: ['90'],
#  734: ['Presto'],
#  735: ['V2'],
#  736: ['V2'],
#  737: ['V2'],
#  738: ['V2'],
#  739: ['V2'],
#  740: ['V2'],
#  741: ['V2'],
#  742: ['V2'],
#  743: ['V2'],
#  744: ['V2'],
#  745: ['V2'],
#  746: ['V2'],
#  747: ['V2'],
#  748: ['V2'],
#  749: ['V2'],
#  750: ['V2'],
#  751: ['V2'],
#  752: ['V2'],
#  753: ['V2'],
#  754: ['V2'],
#  755: ['V2'],
#  756: ['V2'],
#  757: ['1'],
#  758: ['1'],
#  759: ['90'],
#  760: ['Presto'],
#  761: ['Presto'],
#  762: ['VaporMax'],
#  763: ['Blazer'],
#  764: ['V1'],
#  765: ['V2'],
#  766: ['V2'],
#  767: ['V2'],
#  768: ['V2'],
#  769: ['V2'],
#  770: ['V2'],
#  771: ['V2'],
#  772: ['V2'],
#  773: ['V2'],
#  774: ['V2'],
#  775: ['V2'],
#  776: ['V2'],
#  777: ['V2'],
#  778: ['V2'],
#  779: ['V2'],
#  780: ['V2'],
#  781: ['V2'],
#  782: ['1'],
#  783: ['90'],
#  784: ['Presto'],
#  785: ['VaporMax'],
#  786: ['Blazer'],
#  787: ['V1'],
#  788: ['V2'],
#  789: ['V2'],
#  790: ['V2'],
#  791: ['V2'],
#  792: ['V2'],
#  793: ['V2'],
#  794: ['V2'],
#  795: ['V2'],
#  796: ['V2'],
#  797: ['V2'],
#  798: ['V2'],
#  799: ['V2'],
#  800: ['V2'],
#  801: ['90'],
#  802: ['V2'],
#  803: ['V2'],
#  804: ['V2'],
#  805: ['V2'],
#  806: ['V2'],
#  807: ['V2'],
#  808: ['V2'],
#  809: ['V2'],
#  810: ['V2'],
#  811: ['V2'],
#  812: ['V2'],
#  813: ['V2'],
#  814: ['V2'],
#  815: ['1'],
#  816: ['Presto'],
#  817: ['Presto'],
#  818: ['VaporMax'],
#  819: ['V2'],
#  820: ['V2'],
#  821: ['V2'],
#  822: ['V2'],
#  823: ['V2'],
#  824: ['V2'],
#  825: ['V2'],
#  826: ['V2'],
#  827: ['V2'],
#  828: ['V2'],
#  829: ['V2'],
#  830: ['V2'],
#  831: ['V2'],
#  832: ['V2'],
#  833: ['90'],
#  834: ['Presto'],
#  835: ['V1'],
#  836: ['V2'],
#  837: ['V2'],
#  838: ['V2'],
#  839: ['V2'],
#  840: ['V2'],
#  841: ['V2'],
#  842: ['V2'],
#  843: ['V2'],
#  844: ['V2'],
#  845: ['V2'],
#  846: ['V2'],
#  847: ['V2'],
#  848: ['V2'],
#  849: ['1'],
#  850: ['90'],
#  851: ['Presto'],
#  852: ['VaporMax'],
#  853: ['V2'],
#  854: ['V2'],
#  855: ['V2'],
#  856: ['V2'],
#  857: ['V2'],
#  858: ['V2'],
#  859: ['V2'],
#  860: ['V2'],
#  861: ['V2'],
#  862: ['V2'],
#  863: ['V2'],
#  864: ['V2'],
#  865: ['1'],
#  866: ['VaporMax'],
#  867: ['V1'],
#  868: ['V2'],
#  869: ['V2'],
#  870: ['V2'],
#  871: ['V2'],
#  872: ['V2'],
#  873: ['V2'],
#  874: ['V2'],
#  875: ['V2'],
#  876: ['V2'],
#  877: ['V2'],
#  878: ['V2'],
#  879: ['V2'],
#  880: ['V2'],
#  881: ['V2'],
#  882: ['V2'],
#  883: ['V2'],
#  884: ['1'],
#  885: ['90'],
#  886: ['Presto'],
#  887: ['VaporMax'],
#  888: ['V2'],
#  889: ['V2'],
#  890: ['V2'],
#  891: ['V2'],
#  892: ['V2'],
#  893: ['V2'],
#  894: ['V2'],
#  895: ['V2'],
#  896: ['V2'],
#  897: ['V2'],
#  898: ['V2'],
#  899: ['V2'],
#  900: ['V2'],
#  901: ['Presto'],
#  902: ['VaporMax'],
#  903: ['V1'],
#  904: ['V2'],
#  905: ['V2'],
#  906: ['V2'],
#  907: ['V2'],
#  908: ['V2'],
#  909: ['V2'],
#  910: ['V2'],
#  911: ['V2'],
#  912: ['V2'],
#  913: ['V2'],
#  914: ['V2'],
#  915: ['V2'],
#  916: ['V2'],
#  917: ['V2'],
#  918: ['V2'],
#  919: ['V1'],
#  920: ['V1'],
#  921: ['V1'],
#  922: ['V1'],
#  923: ['V1'],
#  924: ['V1'],
#  925: ['V1'],
#  926: ['V1'],
#  927: ['V1'],
#  928: ['V2'],
#  929: ['V2'],
#  930: ['V2'],
#  931: ['V2'],
#  932: ['V2'],
#  933: ['V2'],
#  934: ['V2'],
#  935: ['V2'],
#  936: ['V2'],
#  937: ['V2'],
#  938: ['V2'],
#  939: ['V2'],
#  940: ['V2'],
#  941: ['V2'],
#  942: ['V2'],
#  943: ['V2'],
#  944: ['V2'],
#  945: ['V2'],
#  946: ['V2'],
#  947: ['V2'],
#  948: ['V2'],
#  949: ['V2'],
#  950: ['V2'],
#  951: ['V2'],
#  952: ['V2'],
#  953: ['V2'],
#  954: ['V2'],
#  955: ['V2'],
#  956: ['V2'],
#  957: ['V2'],
#  958: ['V2'],
#  959: ['V2'],
#  960: ['V2'],
#  961: ['V2'],
#  962: ['V2'],
#  963: ['V2'],
#  964: ['V2'],
#  965: ['V2'],
#  966: ['V2'],
#  967: ['V2'],
#  968: ['V2'],
#  969: ['V2'],
#  970: ['V2'],
#  971: ['V2'],
#  972: ['V2'],
#  973: ['V2'],
#  974: ['V2'],
#  975: ['V2'],
#  976: ['V2'],
#  977: ['V2'],
#  978: ['V2'],
#  979: ['V2'],
#  980: ['V2'],
#  981: ['V2'],
#  982: ['V2'],
#  983: ['V2'],
#  984: ['V2'],
#  985: ['V2'],
#  986: ['V2'],
#  987: ['V2'],
#  988: ['V2'],
#  989: ['V2'],
#  990: ['V2'],
#  991: ['V2'],
#  992: ['V2'],
#  993: ['V2'],
#  994: ['V2'],
#  995: ['V2'],
#  996: ['V2'],
#  997: ['V2'],
#  998: ['V2'],
#  999: ['V2'],
#  ...}

# %%
versionstuff = []

for x in versiondict.values():
    if len(x) == 1:
        versionstuff.append(x[0])
    else:
    
        versionstuff.append(0) 


shoes = shoes.with_column('Version', versionstuff)

# %%
shoes.show(3000)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Order Date</th> <th>Brand</th> <th>Sneaker Name</th> <th>Sale Price</th> <th>Retail Price</th> <th>Release Date</th> <th>Shoe Size</th> <th>Buyer Region</th> <th>Colors</th> <th>Version</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-Low-V2-Beluga             </td> <td>$1,097    </td> <td>$220        </td> <td>9/24/16     </td> <td>11       </td> <td>California          </td> <td>['Beluga']          </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Copper      </td> <td>$685      </td> <td>$220        </td> <td>11/23/16    </td> <td>11       </td> <td>California          </td> <td>['Black', 'Copper'] </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Green       </td> <td>$690      </td> <td>$220        </td> <td>11/23/16    </td> <td>11       </td> <td>California          </td> <td>['Black', 'Green']  </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red         </td> <td>$1,075    </td> <td>$220        </td> <td>11/23/16    </td> <td>11.5     </td> <td>Kentucky            </td> <td>['Black', 'Red']    </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017    </td> <td>$828      </td> <td>$220        </td> <td>2/11/17     </td> <td>11       </td> <td>Rhode Island        </td> <td>['Black', 'Red']    </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017    </td> <td>$798      </td> <td>$220        </td> <td>2/11/17     </td> <td>8.5      </td> <td>Michigan            </td> <td>['Black', 'Red']    </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-White       </td> <td>$784      </td> <td>$220        </td> <td>12/17/16    </td> <td>11       </td> <td>California          </td> <td>['Black', 'White']  </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Cream-White            </td> <td>$460      </td> <td>$220        </td> <td>4/29/17     </td> <td>10       </td> <td>New York            </td> <td>['Cream', 'White']  </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Cream-White            </td> <td>$465      </td> <td>$220        </td> <td>4/29/17     </td> <td>11       </td> <td>Kansas              </td> <td>['Cream', 'White']  </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Cream-White            </td> <td>$465      </td> <td>$220        </td> <td>4/29/17     </td> <td>11       </td> <td>Florida             </td> <td>['Cream', 'White']  </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Cream-White            </td> <td>$515      </td> <td>$220        </td> <td>4/29/17     </td> <td>11.5     </td> <td>New Jersey          </td> <td>['Cream', 'White']  </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Cream-White            </td> <td>$473      </td> <td>$220        </td> <td>4/29/17     </td> <td>10       </td> <td>Texas               </td> <td>['Cream', 'White']  </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Cream-White            </td> <td>$460      </td> <td>$220        </td> <td>4/29/17     </td> <td>9        </td> <td>Florida             </td> <td>['Cream', 'White']  </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>$570      </td> <td>$220        </td> <td>2/25/17     </td> <td>14       </td> <td>Michigan            </td> <td>['Zebra']           </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>$525      </td> <td>$220        </td> <td>2/25/17     </td> <td>8        </td> <td>New York            </td> <td>['Zebra']           </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>$658      </td> <td>$220        </td> <td>2/25/17     </td> <td>11       </td> <td>California          </td> <td>['Zebra']           </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>$650      </td> <td>$220        </td> <td>2/25/17     </td> <td>11       </td> <td>North Carolina      </td> <td>['Zebra']           </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>$610      </td> <td>$220        </td> <td>2/25/17     </td> <td>10       </td> <td>New Jersey          </td> <td>['Zebra']           </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>$589      </td> <td>$220        </td> <td>2/25/17     </td> <td>9        </td> <td>New York            </td> <td>['Zebra']           </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>$850      </td> <td>$220        </td> <td>2/25/17     </td> <td>5.5      </td> <td>Michigan            </td> <td>['Zebra']           </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>$546      </td> <td>$220        </td> <td>2/25/17     </td> <td>9        </td> <td>Florida             </td> <td>['Zebra']           </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>$586      </td> <td>$220        </td> <td>2/25/17     </td> <td>9.5      </td> <td>Oregon              </td> <td>['Zebra']           </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/1/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Zebra                  </td> <td>$640      </td> <td>$220        </td> <td>2/25/17     </td> <td>14       </td> <td>California          </td> <td>['Zebra']           </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/2/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-Low-V2-Beluga             </td> <td>$850      </td> <td>$220        </td> <td>9/24/16     </td> <td>8        </td> <td>Alabama             </td> <td>['Beluga']          </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/2/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red         </td> <td>$999      </td> <td>$220        </td> <td>11/23/16    </td> <td>11       </td> <td>Kentucky            </td> <td>['Black', 'Red']    </td> <td>V2       </td>
#         </tr>
#         <tr>
#             <td>9/2/17    </td> <td> Yeezy   </td> <td>Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017    </td> <td>$740      </td> <td>$220        </td> <td>2/11/17     </td> <td>9        </td> <td>New Yor

# %%
# Just run this cell.

def plot_with_two_features(test_song, training_songs, x_feature, y_feature):
    """Plot a test song and training songs using two features."""
    test_row = row_for_title(test_song)
    distances = Table().with_columns(
            x_feature, [test_row.item(x_feature)],
            y_feature, [test_row.item(y_feature)],
            'Color',   ['Unknown'],
            'Title',   [test_song]
        )
    for song in training_songs:
        row = row_for_title(song)
        distances.append([row.item(x_feature), row.item(y_feature), row.item('Genre'), song])
    distances.scatter(x_feature, y_feature, colors='Color', labels='Title', s=200)
    
training = ["Sangria Wine", "Insane In The Brain"]
plot_with_two_features("In Your Eyes", training, "like", "love")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-5e69630e5186> in <module>
#      16
#      17 training = ["Sangria Wine", "Insane In The Brain"]
# ---> 18 plot_with_two_features("In Your Eyes", training, "like", "love")
#
# <ipython-input-53-5e69630e5186> in plot_with_two_features(test_song, training_songs, x_feature, y_feature)
#       3 def plot_with_two_features(test_song, training_songs, x_feature, y_feature):
#       4     """Plot a test song and training songs using two features."""
# ----> 5     test_row = row_for_title(test_song)
#       6     distances = Table().with_columns(
#       7             x_feature, [test_row.item(x_feature)],
#
# NameError: name 'row_for_title' is not defined

# %%
def distance_two_features(title0, title1, x_feature, y_feature):
    """Compute the distance between two songs with titles title0 and title1
    
    Only the features named x_feature and y_feature are used when computing the distance.
    """
    row0 = row_for_title(title0)
    row1 = row_for_title(title1)
    x1 = row0.item(x_feature)
    x2 = row1.item(x_feature)
    y1 = row0.item(y_feature)
    y2 = row1.item(y_feature)
    return ((x2-x1)**2 +(y2-y1)**2)**(1/2)
for song in make_array("Lookin' for Love", "Insane In The Brain"):
    song_distance = distance_two_features(song, "In Your Eyes", "like", "love")
    print(song, 'distance:\t', song_distance)

# %%
def distance_from_in_your_eyes(title):
    """The distance between the given song and "In Your Eyes", based on the features "like" and "love".
    
    This function takes a single argument:
      title: A string, the name of a song.
    """
    return distance_two_features('In Your Eyes', title, 'like', 'love')

# %%
def most_common(label, table):
    """The most common element in a column of a table.
    
    This function takes two arguments:
      label: The label of a column, a string.
      table: A table.
     
    It returns the most common value in that column of that table.
    In case of a tie, it returns any one of the most common values
    """
    koo = train_lyrics.apply(distance_from_in_your_eyes, 'Title')
    ko = train_lyrics.select('Title', 'Artist', 'Genre', 'like', 'love').with_column('distance', koo)
    close_songs = ko.sort('distance').take(np.arange(7))
    close_songs
    return table.group(label).sort('count', descending=True).column(label)[0]


# Calling most_common on your table of 7 nearest neighbors classifies
# "In Your Eyes" as a country song, 4 votes to 3.
most_common('Genre', close_songs)

# %%
def distance(features1, features2):
    """The Euclidean distance between two arrays of feature values."""
    
    x = np.array(features1).astype(np.float)
    y = np.array(features2).astype(np.float)
    distance = (sum(((x-y)**2)))**(1/2)
    return distance

distance_first_to_first = distance(train_lyrics.drop('Title', 'Artist', 'Genre').row(0), test_lyrics.drop('Title', 'Artist', 'Genre').row(0))
distance_first_to_first

# %%
# Just run this cell to define fast_distances.

def fast_distances(test_row, train_rows):
    """An array of the distances between test_row and each row in train_rows.

    Takes 2 arguments:
      test_row: A row of a table containing features of one
        test song (e.g., test_20.row(0)).
      train_rows: A table of features (for example, the whole
        table train_20)."""
    assert train_rows.num_columns < 50, "Make sure you're not using all the features of the lyrics table."
    counts_matrix = np.asmatrix(train_rows.columns).transpose()
    diff = np.tile(np.array(test_row), [counts_matrix.shape[0], 1]) - counts_matrix
    distances = np.squeeze(np.asarray(np.sqrt(np.square(diff).sum(1))))
    return distances

# %%
def classify(test_row, train_rows, train_classes, k):
    """Return the most common class among k nearest neigbors to test_row."""
    distances = fast_distances(test_row, train_rows)
    genre_and_distances = Table().with_columns('Genre', train_lyrics.column('Genre'), 'Distance', distances).sort('Distance',descending=False)
    genre = genre_and_distances.take(np.arange(0,k)).group('Genre').sort('count', descending=True).column('Genre').item(0)
    return genre

# %%
def classify_one_argument(row):
    gen = classify(row, train_20, my_20_features,  5)
    return gen

# When you're done, this should produce 'Hip-hop' or 'Country'.
classify_one_argument(test_20.row(0))

# %%
#standard deviation

yzy = shoes.where('Brand', are.containing('Yeezy'))

total = 0
for price in yzy.column("Sale Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    total += float(new_price)
    
avg = total/len(yzy.column("Sale Price"))

avg_lst = []
for price in yzy.column("Sale Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    avg_lst.append((float(new_price)-avg)**2)

yzy_stndrd = (sum(avg_lst)/len(avg_lst))**0.5

# %%
yzy_stndrd
# Out:
# 143.73114169435306

# %%
#yzy average

sale_yzy_total = 0
for price in yzy.column("Sale Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    sale_yzy_total += float(new_price)

sale_yzy_avg = sale_yzy_total/len(yzy.column('Sale Price'))
    
retail_yzy_total = 0
for price in yzy.column("Retail Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    retail_yzy_total += float(new_price)
    
retail_yzy_avg = retail_yzy_total/len(yzy.column('Retail Price'))


sharpe_yzy = (sale_yzy_avg - retail_yzy_avg)/yzy_stndrd

# %%
sharpe_yzy
# Out:
# 0.9751446712146034

# %%
#off_white standard deviation
off_white = shoes.where('Brand', are.containing('Off-White'))

total = 0
for price in off_white.column("Sale Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    total += float(new_price)
    
avg = total/len(off_white.column("Sale Price"))

avg_lst = []
for price in off_white.column("Sale Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    avg_lst.append((float(new_price)-avg)**2)

off_stndrd = (sum(avg_lst)/len(avg_lst))**0.5

# %%
#off-white average

sale_off_total = 0
for price in off_white.column("Sale Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    sale_off_total += float(new_price)

sale_off_avg = sale_off_total/len(off_white.column('Sale Price'))
    
retail_off_total = 0
for price in off_white.column("Retail Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    retail_off_total += float(new_price)
    
retail_off_avg = retail_off_total/len(off_white.column('Retail Price'))


sharpe_off = (sale_off_avg - retail_off_avg)/off_stndrd

# %%
sharpe_off
# Out:
# 1.4705053138663555

# %%
total = 0
for price in shoes.column("Sale Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    total += float(new_price)

# %%
avg = total/len(shoes.column("Sale Price"))

# %%
avg_lst = []
for price in shoes.column("Sale Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
#  125574.75218225797,
#  57775.46817729579,
#  80295.88231951836,
#  87240.64905688282,
#  124867.02162081093,
#  83154.53512675356,
#  58740.92930018986,
#  162703.5496931628,
#  74728.576705048,
#  92030.49354845911,
#  41357.43740375543,
#  59714.39042308394,
#  54459.354247166535,
#  938.4860251488353,
#  709.4082709369823,
#  1000.7554637017986,
#  819.9471480429088,
#  425.79163961920267,
#  113.09725408957001,
#  19.05567579512104,
#  2339.2003794647376,
#  19144.950909698044,
#  6.941745665863898,
#  763.6777094899455,
#  9675.728451816574,
#  44.01949987771696,
#  13.211184218827164,
#  1131.2943408077251,
#  21.48062277179043,
#  468.06107817216594,
#  468.06107817216594,
#  11.325114348084306,
#  244.44444685438634,
#  1549.6253264414067,
#  468.06107817216594,
#  468.06107817216594,
#  11.325114348084306,
#  11.325114348084306,
#  468.06107817216594,
#  20553.603716933227,
#  ...]

# %%
stndrd = (sum(avg_lst)/len(avg_lst))**0.5

# %%
sum(avg_lst)
# Out:
# 6549779306.868528

# %%
avg
# Out:
# 446.63471927648163

# %%
total = 0
for price in shoes.column("Retail Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    total += float(new_price)

# %%
retl_avg = total/len(shoes.column("Retail Price"))

# %%
sum(retl_lst)/len(retl_lst)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-bc3c0b53f4a7> in <module>
# ----> 1 sum(retl_lst)/len(retl_lst)
#
# NameError: name 'retl_lst' is not defined

# %%
sharpe = (avg - retl_avg)/stndrd

# %%
sharpe
# Out:
# 0.9298365473224922

# %%
yzy = shoes.where('Brand', are.containing('Yeezy'))

# %%
avg_lst = []
for price in shoes.column("Sale Price"):
    new_price = ""
    for i in price:
        if i.isdigit():
            new_price+=i
    avg_lst.append((float(new_price)-avg)**2)

# %%
shoes.column("Order Date")
# Out:
# array(['9/1/17', '9/1/17', '9/1/17', ..., '2/13/19', '2/13/19', '2/13/19'],
#       dtype='<U8')

# %%
def get_sharpe(color, column):

    
    yzy = shoes.where(column, are.containing(color))

    total = 0
    for price in yzy.column("Sale Price"):
        new_price = ""
        for i in price:
            if i.isdigit():
                new_price+=i
        total += float(new_price)

    avg = total/len(yzy.column("Sale Price"))

    avg_lst = []
    for price in yzy.column("Sale Price"):
        new_price = ""
        for i in price:
            if i.isdigit():
                new_price+=i
        avg_lst.append((float(new_price)-avg)**2)

    yzy_stndrd = (sum(avg_lst)/len(avg_lst))**0.5

    
    sale_yzy_total = 0
    for price in yzy.column("Sale Price"):
        new_price = ""
        for i in price:
            if i.isdigit():
                new_price+=i
        sale_yzy_total += float(new_price)

    sale_yzy_avg = sale_yzy_total/len(yzy.column('Sale Price'))

    retail_yzy_total = 0
    for price in yzy.column("Retail Price"):
        new_price = ""
        for i in price:
            if i.isdigit():
                new_price+=i
        retail_yzy_total += float(new_price)

    retail_yzy_avg = retail_yzy_total/len(yzy.column('Retail Price'))


    sharpe_yzy = (sale_yzy_avg - retail_yzy_avg)/yzy_stndrd
    return sharpe_yzy

# %%
color_sharpe = []
color_name = []
for color in colors:
    color_sharpe.append(get_sharpe(color, 'Colors'))
    color_name.append(color)

# %%
color_table = Table().with_columns('Color', color_name, "Sharpe Ratio",color_sharpe)
color_table.barh("Color")

# %%
colors = ['Beluga','Cream', 'White','Copper','Green','Red','Zebra','Black','Moonrock','Chicago','Tan','Turtledove','Blue','Yellow','Butter','Sesame','Static','Reflective','Desert','University','Volt','Pink','Silver','Eve','Rose','Menta','Reaper','Orange']

# %%
shoes_lst = list(shoes.column('Buyer Region'))

# %%
shoes_set = set(shoes_lst)

# %%
shoes_set
# Out:
# {'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming'}

# %%
sharpe = []
for state in shoes_set:
    sharpe.append(get_sharpe(state, 'Buyer Region'))

# %%
sharpe_ratio = Table().with_columns('state',shoes_set, 'sharpe',sharpe)
sharpe_ratio.barh('state')

# %%
api = 'https://datausa.io/api/data?drilldowns=State&measures=Population&year=latest'

# %%
import json
import urllib.request

url = urllib.request.urlopen(api).read()
url
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-95-9698c6d589f5> in <module>
#       2 import urllib.request
#       3
# ----> 4 url = urllib.request.urlopen(api).read()
#       5 url
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
pop = json.loads(api.read())

# %%
rl = """{"data":[{"ID State":"04000US01","State":"Alabama","ID Year":2019,"Year":"2019","Population":4903185,"Slug State":"alabama"},{"ID State":"04000US02","State":"Alaska","ID Year":2019,"Year":"2019","Population":731545,"Slug State":"alaska"},{"ID State":"04000US04","State":"Arizona","ID Year":2019,"Year":"2019","Population":7278717,"Slug State":"arizona"},{"ID State":"04000US05","State":"Arkansas","ID Year":2019,"Year":"2019","Population":3017804,"Slug State":"arkansas"},{"ID State":"04000US06","State":"California","ID Year":2019,"Year":"2019","Population":39512223,"Slug State":"california"},{"ID State":"04000US08","State":"Colorado","ID Year":2019,"Year":"2019","Population":5758736,"Slug State":"colorado"},{"ID State":"04000US09","State":"Connecticut","ID Year":2019,"Year":"2019","Population":3565287,"Slug State":"connecticut"},{"ID State":"04000US10","State":"Delaware","ID Year":2019,"Year":"2019","Population":973764,"Slug State":"delaware"},{"ID State":"04000US11","State":"District of Columbia","ID Year":2019,"Year":"2019","Population":705749,"Slug State":"district-of-columbia"},{"ID State":"04000US12","State":"Florida","ID Year":2019,"Year":"2019","Population":21477737,"Slug State":"florida"},{"ID State":"04000US13","State":"Georgia","ID Year":2019,"Year":"2019","Population":10617423,"Slug State":"georgia"},{"ID State":"04000US15","State":"Hawaii","ID Year":2019,"Year":"2019","Population":1415872,"Slug State":"hawaii"},{"ID State":"04000US16","State":"Idaho","ID Year":2019,"Year":"2019","Population":1787065,"Slug State":"idaho"},{"ID State":"04000US17","State":"Illinois","ID Year":2019,"Year":"2019","Population":12671821,"Slug State":"illinois"},{"ID State":"04000US18","State":"Indiana","ID Year":2019,"Year":"2019","Population":6732219,"Slug State":"indiana"},{"ID State":"04000US19","State":"Iowa","ID Year":2019,"Year":"2019","Population":3155070,"Slug State":"iowa"},{"ID State":"04000US20","State":"Kansas","ID Year":2019,"Year":"2019","Population":2913314,"Slug State
population":28995881,"Slug State":"texas"},{"ID State":"04000US49","State":"Utah","ID Year":2019,"Year":"2019","Population":3205958,"Slug State":"utah"},{"ID State":"04000US50","State":"Vermont","ID Year":2019,"Year":"2019","Population":623989,"Slug State":"vermont"},{"ID State":"04000US51","State":"Virginia","ID Year":2019,"Year":"2019","Population":8535519,"Slug State":"virginia"},{"ID State":"04000US53","State":"Washington","ID Year":2019,"Year":"2019","Population":7614893,"Slug State":"washington"},{"ID State":"04000US54","State":"West Virginia","ID Year":2019,"Year":"2019","Population":1792147,"Slug State":"west-virginia"},{"ID State":"04000US55","State":"Wisconsin","ID Year":2019,"Year":"2019","Population":5822434,"Slug State":"wisconsin"},{"ID State":"04000US56","State":"Wyoming","ID Year":2019,"Year":"2019","Population":578759,"Slug State":"wyoming"},{"ID State":"04000US72","State":"Puerto Rico","ID Year":2019,"Year":"2019","Population":3193694,"Slug State":"puerto-rico"}],"source":[{"measures":["Population"],"annotations":{"source_name":"Census Bureau","source_description":"The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.","dataset_name":"ACS 1-year Estimate","dataset_link":"http://www.census.gov/programs-surveys/acs/","table_id":"B01003","topic":"Diversity","subtopic":"Demographics"},"name":"acs_yg_total_population_1","substitutions":[]}]}"""

# %%
pop = json.loads(rl)
pop
# Out:
# {'data': [{'ID State': '04000US01',
#    'State': 'Alabama',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 4903185,
#    'Slug State': 'alabama'},
#   {'ID State': '04000US02',
#    'State': 'Alaska',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 731545,
#    'Slug State': 'alaska'},
#   {'ID State': '04000US04',
#    'State': 'Arizona',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 7278717,
#    'Slug State': 'arizona'},
#   {'ID State': '04000US05',
#    'State': 'Arkansas',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3017804,
#    'Slug State': 'arkansas'},
#   {'ID State': '04000US06',
#    'State': 'California',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 39512223,
#    'Slug State': 'california'},
#   {'ID State': '04000US08',
#    'State': 'Colorado',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 5758736,
#    'Slug State': 'colorado'},
#   {'ID State': '04000US09',
#    'State': 'Connecticut',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3565287,
#    'Slug State': 'connecticut'},
#   {'ID State': '04000US10',
#    'State': 'Delaware',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 973764,
#    'Slug State': 'delaware'},
#   {'ID State': '04000US11',
#    'State': 'District of Columbia',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 705749,
#    'Slug State': 'district-of-columbia'},
#   {'ID State': '04000US12',
#    'State': 'Florida',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 21477737,
#    'Slug State': 'florida'},
#   {'ID State': '04000US13',
#    'State': 'Georgia',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 10617423,
#    'Slug State': 'georgia'},
#   {'ID State': '04000US15',
#    'State': 'Hawaii',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1415872,
#    'Slug State': 'hawaii'},
#   {'ID State': '04000US16',
#    'State': 'Idaho',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1787065,
#    'Slug State': 'idaho'},
#   {'ID State': '04000US17',
#    'State': 'Illinois',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 12671821,
#    'Slug State': 'illinois'},
#   {'ID State': '04000US18',
#    'State': 'Indiana',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 6732219,
#    'Slug State': 'indiana'},
#   {'ID State': '04000US19',
#    'State': 'Iowa',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3155070,
#    'Slug State': 'iowa'},
#   {'ID State': '04000US20',
#    'State': 'Kansas',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 2913314,
#    'Slug State': 'kansas'},
#   {'ID State': '04000US21',
#    'State': 'Kentucky',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 4467673,
#    'Slug State': 'kentucky'},
#   {'ID State': '04000US22',
#    'State': 'Louisiana',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 4648794,
#    'Slug State': 'louisiana'},
#   {'ID State': '04000US23',
#    'State': 'Maine',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1344212,
#    'Slug State': 'maine'},
#   {'ID State': '04000US24',
#    'State': 'Maryland',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 6045680,
#    'Slug State': 'maryland'},
#   {'ID State': '04000US25',
#    'State': 'Massachusetts',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 6892503,
#    'Slug State': 'massachusetts'},
#   {'ID State': '04000US26',
#    'State': 'Michigan',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 9986857,
#    'Slug State': 'michigan'},
#   {'ID State': '04000US27',
#    'State': 'Minnesota',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 5639632,
#    'Slug State': 'minnesota'},
#   {'ID State': '04000US28',
#    'State': 'Mississippi',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 2976149,
#    'Slug State': 'mississippi'},
#   {'ID State': '04000US29',
#    'State': 'Missouri',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 6137428,
#    'Slug State': 'missouri'},
#   {'ID State': '04000US30',
#    'State': 'Montana',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1068778,
#    'Slug State': 'montana'},
#   {'ID State': '04000US31',
#    'State': 'Nebraska',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1934408,
#    'Slug State': 'nebraska'},
#   {'ID State': '04000US32',
#    'State': 'Nevada',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3080156,
#    'Slug State': 'nevada'},
#   {'ID State': '04000US33',
#    'State': 'New Hampshire',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1359711,
#    'Slug State': 'new-hampshire'},
#   {'ID State': '04000US34',
#    'State': 'New Jersey',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 8882190,
#    'Slug State': 'new-jersey'},
#   {'ID State': '04000US35',
#    'State': 'New Mexico',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 2096829,
#    'Slug State': 'new-mexico'},
#   {'ID State': '04000US36',
#    'State': 'New York',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 19453561,
#    'Slug State': 'new-york'},
#   {'ID State': '04000US37',
#    'State': 'North Carolina',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 10488084,
#    'Slug State': 'north-carolina'},
#   {'ID State': '04000US38',
#    'State': 'North Dakota',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 762062,
#    'Slug State': 'north-dakota'},
#   {'ID State': '04000US39',
#    'State': 'Ohio',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 11689100,
#    'Slug State': 'ohio'},
#   {'ID State': '04000US40',
#    'State': 'Oklahoma',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3956971,
#    'Slug State': 'oklahoma'},
#   {'ID State': '04000US41',
#    'State': 'Oregon',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 4217737,
#    'Slug State': 'oregon'},
#   {'ID State': '04000US42',
#    'State': 'Pennsylvania',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 12801989,
#    'Slug State': 'pennsylvania'},
#   {'ID State': '04000US44',
#    'State': 'Rhode Island',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1059361,
#    'Slug State': 'rhode-island'},
#   {'ID State': '04000US45',
#    'State': 'South Carolina',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 5148714,
#    'Slug State': 'south-carolina'},
#   {'ID State': '04000US46',
#    'State': 'South Dakota',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 884659,
#    'Slug State': 'south-dakota'},
#   {'ID State': '04000US47',
#    'State': 'Tennessee',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 6829174,
#    'Slug State': 'tennessee'},
#   {'ID State': '04000US48',
#    'State': 'Texas',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 28995881,
#    'Slug State': 'texas'},
#   {'ID State': '04000US49',
#    'State': 'Utah',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3205958,
#    'Slug State': 'utah'},
#   {'ID State': '04000US50',
#    'State': 'Vermont',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 623989,
#    'Slug State': 'vermont'},
#   {'ID State': '04000US51',
#    'State': 'Virginia',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 8535519,
#    'Slug State': 'virginia'},
#   {'ID State': '04000US53',
#    'State': 'Washington',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 7614893,
#    'Slug State': 'washington'},
#   {'ID State': '04000US54',
#    'State': 'West Virginia',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 1792147,
#    'Slug State': 'west-virginia'},
#   {'ID State': '04000US55',
#    'State': 'Wisconsin',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 5822434,
#    'Slug State': 'wisconsin'},
#   {'ID State': '04000US56',
#    'State': 'Wyoming',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 578759,
#    'Slug State': 'wyoming'},
#   {'ID State': '04000US72',
#    'State': 'Puerto Rico',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 3193694,
#    'Slug State': 'puerto-rico'}],
#  'source': [{'measures': ['Population'],
#    'annotations': {'source_name': 'Census Bureau',
#     'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#     'dataset_name': 'ACS 1-year Estimate',
#     'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#     'table_id': 'B01003',
#     'topic': 'Diversity',
#     'subtopic': 'Demographics'},
#    'name': 'acs_yg_total_population_1',
#    'substitutions': []}]}

# %%
state_pop = []
count = 0
for state in shoes_set:
    print(pop['data'][count]['Population'], pop['data'][count]['State'])
   
    state_pop.append(pop['data'][count]["Population"]/1e7)
    
    count += 1
# Out:
# 4903185 Alabama
# 731545 Alaska
# 7278717 Arizona
# 3017804 Arkansas
# 39512223 California
# 5758736 Colorado
# 3565287 Connecticut
# 973764 Delaware
# 705749 District of Columbia
# 21477737 Florida
# 10617423 Georgia
# 1415872 Hawaii
# 1787065 Idaho
# 12671821 Illinois
# 6732219 Indiana
# 3155070 Iowa
# 2913314 Kansas
# 4467673 Kentucky
# 4648794 Louisiana
# 1344212 Maine
# 6045680 Maryland
# 6892503 Massachusetts
# 9986857 Michigan
# 5639632 Minnesota
# 2976149 Mississippi
# 6137428 Missouri
# 1068778 Montana
# 1934408 Nebraska
# 3080156 Nevada
# 1359711 New Hampshire
# 8882190 New Jersey
# 2096829 New Mexico
# 19453561 New York
# 10488084 North Carolina
# 762062 North Dakota
# 11689100 Ohio
# 3956971 Oklahoma
# 4217737 Oregon
# 12801989 Pennsylvania
# 1059361 Rhode Island
# 5148714 South Carolina
# 884659 South Dakota
# 6829174 Tennessee
# 28995881 Texas
# 3205958 Utah
# 623989 Vermont
# 8535519 Virginia
# 7614893 Washington
# 1792147 West Virginia
# 5822434 Wisconsin
# 578759 Wyoming

# %%
for thing in pop['data'][0]:
    print(
    #print(thing['ID State'])
# Out:
#   File "<ipython-input-89-e93f1121d278>", line 3
#     #print(thing['ID State'])
#                              ^
# SyntaxError: unexpected EOF while parsing

# %%
print(pop['data'][0])
# Out:
# {'ID State': '04000US01', 'State': 'Alabama', 'ID Year': 2019, 'Year': '2019', 'Population': 4903185, 'Slug State': 'alabama'}

# %%
sharpe_pop = sharpe_ratio.with_column('Population', state_pop)

# %%
sharpe_pop.drop(0).exclude(4).exclude(-8).plot()

# %%
sharpe_pop.drop(0).exclude(4).exclude(-8).scatter(0, fit_line=True)
plot.pyplot.savefig('graph.jpg')

# %%
#plot.plot(range(80))

#plot.savefig('graph.jpg')
plot.pyplot.savefig('graph.jpg')

# %%
sharpe_pop = sharpe_ratio.with_column('Population', state_pop)
